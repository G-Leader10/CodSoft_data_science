# %%
import numpy as np
import pandas as pd

# %%
import os

# %%
for dirname, _, filesnames in os.walk('D:\arsene\codsoft'):
    for filename in filesnames:
        print(os.path.join(dirname, filename))

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\administrator\anaconda3\lib\site-packages (2.1.0)
# Requirement already satisfied: numpy in c:\users\administrator\anaconda3\lib\site-packages (from xgboost) (1.24.3)
# Requirement already satisfied: scipy in c:\users\administrator\anaconda3\lib\site-packages (from xgboost) (1.11.1)

# %%
# !pip install scikit-plot
# Out:
# Requirement already satisfied: scikit-plot in c:\users\administrator\anaconda3\lib\site-packages (0.3.7)
# Requirement already satisfied: matplotlib>=1.4.0 in c:\users\administrator\anaconda3\lib\site-packages (from scikit-plot) (3.7.2)
# Requirement already satisfied: scikit-learn>=0.18 in c:\users\administrator\anaconda3\lib\site-packages (from scikit-plot) (1.3.0)
# Requirement already satisfied: scipy>=0.9 in c:\users\administrator\anaconda3\lib\site-packages (from scikit-plot) (1.11.1)
# Requirement already satisfied: joblib>=0.10 in c:\users\administrator\anaconda3\lib\site-packages (from scikit-plot) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\administrator\anaconda3\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\administrator\anaconda3\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\administrator\anaconda3\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\administrator\anaconda3\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\administrator\anaconda3\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\administrator\anaconda3\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\administrator\anaconda3\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (10.2.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\administrator\anaconda3\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\administrator\anaconda3\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\administrator\anaconda3\lib\site-packages (from scikit-learn>=0.18->scikit-plot) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\administrator\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=1.4.0->scikit-plot) (1.16.0)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from xgboost import XGBClassifier
from sklearn.ensemble import GradientBoostingClassifier  # Import GradientBoostingClassifier from sklearn.ensemble
from sklearn.model_selection import train_test_split, cross_val_score, LeaveOneOut
from sklearn.metrics import accuracy_score, make_scorer, f1_score, classification_report
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression
import scikitplot as skplt
import warnings
warnings.simplefilter(action='ignore')

# %%
df=pd.read_csv("Titanic-Dataset.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
sns.barplot(x="Sex", y="Fare", data=df)
plt.show()

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.drop(["PassengerId", "Name", "Cabin", "Ticket"], inplace = True, axis = 1 )

# %%
df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df["Age"]=df["Age"].fillna(df["Age"].mean())

# %%
df.dropna(axis=0,inplace=True)

# %%
df.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
df["Embarked"].replace(["C","S","Q"],["Cherbourg","Southampton","Queenstown"])
# Out:
# 0      Southampton
# 1        Cherbourg
# 2      Southampton
# 3      Southampton
# 4      Southampton
#           ...
# 886    Southampton
# 887    Southampton
# 888    Southampton
# 889      Cherbourg
# 890     Queenstown
# Name: Embarked, Length: 889, dtype: object

# %%
plt.figure(figsize=(8, 8))
sns.countplot(x="Survived", data=df)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
plt.figure(figsize=(8, 8))
sns.countplot(x="Survived", data=df, hue="Sex",palette="rainbow")
plt.show()

# %%
plt.figure(figsize=(8, 8))
sns.countplot(x="Pclass", data=df, hue="Survived", palette="brg")
plt.show()

# %%
plt.figure(figsize=(8, 8))
sns.countplot(x="Embarked", data=df, hue="Survived", palette="brg")
plt.show()

# %%
plt.figure(figsize=(8, 8))
sns.countplot(x="Embarked", data=df, hue="Pclass", palette="rainbow")
plt.show()

# %%
plt.figure(figsize=(8, 8))
sns.histplot(x="Age", data=df, palette="rainbow")
plt.show()

# %%
df=pd.get_dummies(df,["sex","Embarked"])

# %%
df
# Out:
#      Survived  Pclass        Age  SibSp  Parch     Fare  sex_female  sex_male  \
# 0           0       3  22.000000      1      0   7.2500       False      True
# 1           1       1  38.000000      1      0  71.2833        True     False
# 2           1       3  26.000000      0      0   7.9250        True     False
# 3           1       1  35.000000      1      0  53.1000        True     False
# 4           0       3  35.000000      0      0   8.0500       False      True
# ..        ...     ...        ...    ...    ...      ...         ...       ...
# 886         0       2  27.000000      0      0  13.0000       False      True
# 887         1       1  19.000000      0      0  30.0000        True     False
# 888         0       3  29.699118      1      2  23.4500        True     False
# 889         1       1  26.000000      0      0  30.0000       False      True
# 890         0       3  32.000000      0      0   7.7500       False      True
#
#      Embarked_C  Embarked_Q  Embarked_S
# 0         False       False        True
# 1          True       False       False
# 2         False       False        True
# 3         False       False        True
# 4         False       False        True
# ..          ...         ...         ...
# 886       False       False        True
# 887       False       False        True
# 888       False       False        True
# 889        True       False       False
# 890       False        True       False
#
# [889 rows x 11 columns]

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
X=df.drop("Survived",axis=1)
y=df["Survived"]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.3,stratify=y,random_state=0)

# %%
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import cross_val_score, LeaveOneOut
from sklearn.metrics import f1_score, make_scorer

ex = ExtraTreesClassifier(n_estimators=110, max_depth=12, random_state=0)
scores = cross_val_score(ex, X_train, y_train, cv=LeaveOneOut(), n_jobs=-1, scoring=make_scorer(f1_score, average="micro"))
print(scores.mean(), scores.std())
# Out:
# 0.7958199356913184 0.40310118537109796

# %%
ex.fit(X_train,y_train)
# Out:
# ExtraTreesClassifier(max_depth=12, n_estimators=110, random_state=0)

# %%
pre=ex.predict(X_test)
print(f1_score(y_test,pre,average="micro"))
# Out:
# 0.842696629213483

# %%
cm = skplt.metrics.confusion_matrix(y_test, pre)
sns.heatmap(cm, annot=True,fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
plt.title(f"ExtraTrees confusion matrix")
plt.show()

# %%
skplt.metrics.plot_roc(y_test,ex.predict_proba(X_test),figsize=(10,8))
plt.show()

# %%
gb=GradientBoostingClassifier(n_estimators=50,max_depth=5)
scores=cross_val_score(gb,X_train,y_train,cv=LeaveOneOut(),n_jobs=-1,scoring=make_scorer(f1_score,average="micro"))
print(scores.mean(),scores.std())
# Out:
# 0.8086816720257235 0.39333907173760874

# %%
gb.fit(X_train,y_train)
# Out:
# GradientBoostingClassifier(max_depth=5, n_estimators=50)

# %%
pre_gb=gb.predict(X_test)
print(f1_score(y_test,pre_gb,average="micro"))
# Out:
# 0.8726591760299626

# %%
cm = skplt.metrics.confusion_matrix(y_test, pre_gb)
sns.heatmap(cm, annot=True,fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
plt.title(f"Gradient Boost confusion matrix")
plt.show()

# %%
skplt.metrics.plot_roc(y_test,gb.predict_proba(X_test),figsize=(10,8))
plt.show()

# %%
lr=LogisticRegression(max_iter=2000,C=1)
scores=cross_val_score(lr,X_train,y_train,cv=LeaveOneOut(),n_jobs=-1,scoring=make_scorer(f1_score,average="micro"))
print(scores.mean(),scores.std())
# Out:
# 0.7845659163987139 0.41112314362507035

# %%
lr.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1, max_iter=2000)

# %%
pre_lr=lr.predict(X_test)
print(f1_score(y_test,pre_lr,average="micro"))
# Out:
# 0.8164794007490637

# %%
cm = skplt.metrics.confusion_matrix(y_test, pre_lr)
sns.heatmap(cm, annot=True,fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
plt.title(f"LogisticRegression confusion matrix")
plt.show()

# %%
skplt.metrics.plot_roc(y_test,lr.predict_proba(X_test),figsize=(10,8))
plt.show()
